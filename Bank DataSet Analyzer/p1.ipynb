# %% [markdown]
# ## Import Libreies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

data = pd.read_csv("test.csv") #load file
data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# #### Data Overview

# %%
data.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# - <b>*Drop similar Value columns*<b>

# %%
data.drop('y',axis=1,inplace=True) #Name of the column I want to delete
data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# - <b>*Quick Data check*<b>

# %%
data.shape
# Out:
# (4521, 16)

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome'],
#       dtype='object')

# %% [markdown]
# - <b>*Seprate Categorical and Numerical*<b>

# %%
cat = data.select_dtypes(include="object").columns
num = data.select_dtypes(exclude="object").columns
print(f"Categorical Columns: {cat}")
print(f"Numerical Columns: {num}")
# Out:
# Categorical Columns: Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome'],
#       dtype='object')
# Numerical Columns: Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
cat.size
# Out:
# 9

# %%
num.size
# Out:
# 7

# %%
data["poutcome"].unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %% [markdown]
# ### Finding the missing Value

# %%
print("Ckeck the null value")
data.isnull().sum()
# Out:
# Ckeck the null value
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %% [markdown]
# #### Replace Duplicates

# %%
data.drop_duplicates(inplace=False)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ## Deriving Insights

# %%
group = data.groupby("age")["balance"].mean()
print(group)
# Out:
# age
# 19     393.500000
# 20     661.333333
# 21    1774.285714
# 22    1455.333333
# 23    2117.950000
#          ...
# 81       1.000000
# 83     380.500000
# 84     639.000000
# 86    1503.000000
# 87     230.000000
# Name: balance, Length: 67, dtype: float64

# %% [markdown]
# - <b>*Correlation and Relationship*<b>

# %%
correlation_value = data["age"].corr(data["balance"])
print(f"Correlation between Age and Balance: {correlation_value}")
# Out:
# Correlation between Age and Balance: 0.08382014224477764

# %% [markdown]
# ## Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("data.csv")

plt.figure(figsize=(10, 6))
sns.histplot(data["age"],bins=30, kde=True, color="red")
plt.grid(True)
plt.title("Distribuation of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - <br>*All Numeric Data*<br>

# %%
plt.figure(figsize=(20, 14))

num = data.select_dtypes(include='number').columns

for idx, col in enumerate(num, 1):
    plt.subplot(3, 3, idx)
    sns.histplot(data[col], kde=True)
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
data = pd.read_csv("data.csv")

corr = data.select_dtypes(include='number').corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
